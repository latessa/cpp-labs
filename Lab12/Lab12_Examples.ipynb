// %% [markdown]
// # Lab 12 Examples (Dijkstra's Single Source Shortest Path)

// %% [markdown]
// Click Shift+Enter in each code cell to run the code. Be sure to start with the `#include` directives to load the required libraries.

// %%
// For Lab 12, we are limited to using only the following #include directives:

#include <iostream>
#include <algorithm>
#include <cmath>
#include <queue>
#include <string>
#include <vector>

// %% [markdown]
// ## Overview
//
// In today's lab, we will implement Dijkstra's single source shortest path algorithm. This algorithm finds the shortest paths from a source node to all other nodes in a weighted graph with non-negative edge weights. The graph can be directed or undirected, but it must not contain negative weight edges.

// %% [markdown]
// ## Representing an Undirected Graph
//
// Graphs are structures made up of nodes (or vertices) connected by edges. They can be represented in code using various methods, such as adjacency matrices or adjacency lists. Below is a simple undirected graph shown visually using an inline SVG; the C++ code cell that follows constructs the same graph as an adjacency list and an adjacency matrix.
//
// <div style="text-align:center">
// <img src="docs/images/Lab12/undirected.svg" style="max-width:100%;height:auto;"/>
// </div>

// %%
int n = 4;

std::vector<std::vector<int>> adjList = {
    {1, 2, 3}, // A: B C D
    {0, 2},    // B: A C
    {0, 1, 3}, // C: A B D
    {0, 2}     // D: A C
};

std::vector<std::vector<int>> adjMatrix = {
//   A  B  C  D
    {0, 1, 1, 1}, // A
    {1, 0, 1, 0}, // B
    {1, 1, 0, 1}, // C
    {1, 0, 1, 0}  // D
};

// Print adjacency list (with letter labels)
std::cout << "Adjacency List:\n";
for (int i = 0; i < n; ++i) {
    std::cout << char('A' + i) << ": ";
    for (int v : adjList[i]) 
        std::cout << char('A' + v) << ' ';
    std::cout << '\n';
}

// Print adjacency matrix
std::cout << "\nAdjacency Matrix:\n";
std::cout << "  ";
for (int i = 0; i < n; ++i) 
    std::cout << char('A' + i) << ' ';
std::cout << '\n';

for (int i = 0; i < n; ++i) {
    std::cout << char('A' + i) << ' ';
    for (int j = 0; j < n; ++j) std::cout << adjMatrix[i][j] << ' ';
        std::cout << '\n';
}
// Out:
// In file included from input_line_5:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/include/xeus/xinterpreter.hpp:13:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/functional:62:
// input_line_5:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/include/xeus/xinterpreter.hpp:13:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/functional:62:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/vector:67:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:401:66: error: no member named 'value' in 'std::is_same<std::vector<int, std::allocator<int> >, std::vector<int, std::allocator<int> > >'
//       static_assert(is_same<typename remove_cv<_Tp>::type, _Tp>::value,
//                     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
// input_line_11In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/vector:67:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:401:66: error: no member named 'value' in 'std::is_same<std::vector<int, std::allocator<int> >, std::vector<int, std::allocator<int> > >'
//       static_assert(is_same<typename remove_cv<_Tp>::type, _Tp>::value,
//                     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
// input_line_11:3:31: note: in instantiation of template class 'std::vector<std::vector<int, std::allocator<int> >, std::allocator<std::vector<int, std::allocator<int> > > >' requested here
// std::vector<std::vector<int>> adjList = {
//                               ^
// In file included from input_line_5:1:
// In file included from :3:31: note: in instantiation of template class 'std::vector<std::vector<int, std::allocator<int> >, std::allocator<std::vector<int, std::allocator<int> > > >' requested here
// std::vector<std::vector<int>> adjList = {
//                               ^
// In file included from input_line_5:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/include/xeus/xinterpreter.hpp:13:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/functional:62:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/vector:67:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:404:64: error/home/jlate/miniforge3/envs/cpp-jupyter/include/xeus/xinterpreter.hpp:13:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/functional:62:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/vector:67:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:404:64: error: no member named 'value' in 'std::is_same<std::vector<int, std::allocator<int> >, std::vector<int, std::allocator<int> > >'
//       static_assert(is_same<typename _Alloc::value_type, _Tp>::value,
//                     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:401:66: : no member named 'value' in 'std::is_same<std::vector<int, std::allocator<int> >, std::vector<int, std::allocator<int> > >'
//       static_assert(is_same<typename _Alloc::value_type, _Tp>::value,
//                     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:401:66: error: no member named 'value' in 'std::is_same<int, int>'
//       static_assert(is_same<typename remove_cv<_Tp>::type, _Tp>::value,
//                     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
// input_line_11:4:5: noteerror: no member named 'value' in 'std::is_same<int, int>'
//       static_assert(is_same<typename remove_cv<_Tp>::type, _Tp>::value,
//                     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
// input_line_11:4:5: note: in instantiation of template class 'std::vector<int, std::allocator<int> >' requested here
//     {1, 2, 3}, // A: B C D
//     ^
// In file included from input_line_5:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/include/xeus/xinterpreter.hpp:13:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/functional:: in instantiation of template class 'std::vector<int, std::allocator<int> >' requested here
//     {1, 2, 3}, // A: B C D
//     ^
// In file included from input_line_5:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/include/xeus/xinterpreter.hpp:13:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/functional:62:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/vector:67:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:404:64: error: no member named 'value' in 'std::is_same<int, int>'
//       static_assert(is_same<typename _Alloc::value_type, _Tp>::value,
//                     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
// In file included from input_line_5:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/include/xeus/xinterpreter.hpp:13:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/functional:61:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/unordered_map:41:
// In file included from 62:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/vector:67:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:404:64: error: no member named 'value' in 'std::is_same<int, int>'
//       static_assert(is_same<typename _Alloc::value_type, _Tp>::value,
//                     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
// In file included from input_line_5:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/include/xeus/xinterpreter.hpp:13:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/functional:61:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/unordered_map:41:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ext/alloc_traits.h:34:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/alloc_traits.h:33:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_construct.h:177:51: error: no member named 'value' in 'std::is_destructible<int>'
//       static_assert(is_destructible<_Value_type>::value,
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ext/alloc_traits.h:34:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/alloc_traits.h:33:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_construct.h:177:51: error: no member named 'value' in 'std::is_destructible<int>'
//       static_assert(is_destructible<_Value_type>::value,
//                     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/alloc_traits.h:842:7: note: in instantiation of function template specialization 'std::_Destroy<int *>' requested here
//       _Destroy(__first, __last);
//       ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:680:7: note: in instantiation of function template specialization 'std::_Destroy<int *, int>' requested here
//         std::_Destroy(this->_M_impl._M_start, this->_M_impl._M_finish,
//              ^
// input_line_11:8:1: note: in instantiation of member function 'std::vector<int, std::allocator<int> >::~vector' requested here
// };
// ^
// In file included from input_line_1:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
//                     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/alloc_traits.h:842:7: note: in instantiation of function template specialization 'std::_Destroy<int *>' requested here
//       _Destroy(__first, __last);
//       ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:680:7: note: in instantiation of function template specialization 'std::_Destroy<int *, int>' requested here
//         std::_Destroy(this->_M_impl._M_start, this->_M_impl._M_finish,
//              ^
// input_line_11:8:1: note: in instantiation of member function 'std::vector<int, std::allocator<int> >::~vector' requested here
// };
// ^
// In file included from input_line_1:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:121:31: error: no member named 'value' in 'std::is_reference<int>'
//     : public conditional<_B1::value, _B1, __or_<_B2, _B3, _Bn...>>::type
//                          ~~~~~^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:206:24: note: in instantiation of template class 'std::__or_<std::is_reference<int>, std::is_function<int>, std::is_void<int>, std::__is_array_unknown_bounds<int> >' requested here
//     constexpr typename __or_<
//                        ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:909:21: note: while substituting deduced template arguments into function template '__is_complete_or_unbounded' [with _TypeIdentity = std::__type_identity<int>, _NestedType = (no value)]
//       static_assert(std::__is_complete_or_unbounded(__type_identity<_Tp>{}),
//                     ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_uninitialized.h:137:21: note: in instantiation of template class 'std::is_constructible<int, const int &>' requested here
//       static_assert(is_constructible<_ValueType2, decltype(*__first)>::value,
//                     ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_uninitialized.h:325:19: note: in instantiation of function template specialization 'std::uninitialized_copy<const int *, int *>' requested here
//     { return std::uninitialized_copy(__first, __last, __result); }
//                   ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:1585:11: note: in instantiation of function template specialization 'std::__uninitialized_copy_a<const int *, int *, int>' requested here
//             std::__uninitialized_copy_a(__first, __last,
//                  ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:629:2: note: in instantiation of function template specialization 'std::vector<int, std::allocator<int> >::_M_range_initialize<const int *>' requested here
//         _M_range_initialize(__l.begin(), __l.end(),
//         ^
// input_line_11:4:5: note: in instantiation of member function 'std::vector<int, std::allocator<int> >::vector' requested here
//     {1, 2, 3}, // A: B C D
//     ^
// In file included from input_line_5:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/include/xeus/xinterpreter.hpp:13:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/functional:62:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/vector:66:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_uninitialized.h:137:72: error: no member named 'value' in 'std::is_constructible<int, const int &>'
//       static_assert(is_constructible<_ValueType2, decltype(*__first)>::value,
//                     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_uninitialized.h:325:19: note: in instantiation of function template specialization 'std::uninitialized_copy<const int *, int *>' requested here
//     { return std::uninitialized_copy(__first, __last, __result); }
//                   ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:1585:11: note: in instantiation of function template specialization 'std::__uninitialized_copy_a<const int *, int *, int>' requested here
//             std::__uninitialized_copy_a(__first, __last,
//                  ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:629:2: note: in instantiation of function template specialization 'std::vector<int, std::allocator<int> >::_M_range_initialize<const int *>' requested here
//         _M_range_initialize(__l.begin(), __l.end(),
//         ^
// input_line_11:4:5: note: in instantiation of member function 'std::vector<int, std::allocator<int> >::vector' requested here
//     {1, 2, 3}, // A: B C D
//     ^
// In file included from input_line_1:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:116:31: error: In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:121:31: error: no member named 'value' in 'std::is_reference<int>'
//     : public conditional<_B1::value, _B1, __or_<_B2, _B3, _Bn...>>::type
//                          ~~~~~^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:206:24: note: in instantiation of template class 'std::__or_<std::is_reference<int>, std::is_function<int>, std::is_void<int>, std::__is_array_unknown_bounds<int> >' requested here
//     constexpr typename __or_<
//                        ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:909:21: note: while substituting deduced template arguments into function template '__is_complete_or_unbounded' [with _TypeIdentity = std::__type_identity<int>, _NestedType = (no value)]
//       static_assert(std::__is_complete_or_unbounded(__type_identity<_Tp>{}),
//                     ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_uninitialized.h:137:21: note: in instantiation of template class 'std::is_constructible<int, const int &>' requested here
//       static_assert(is_constructible<_ValueType2, decltype(*__first)>::value,
//                     ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_uninitialized.h:325:19: note: in instantiation of function template specialization 'std::uninitialized_copy<const int *, int *>' requested here
//     { return std::uninitialized_copy(__first, __last, __result); }
//                   ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:1585:11: note: in instantiation of function template specialization 'std::__uninitialized_copy_a<const int *, int *, int>' requested here
//             std::__uninitialized_copy_a(__first, __last,
//                  ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:629:2: note: in instantiation of function template specialization 'std::vector<int, std::allocator<int> >::_M_range_initialize<const int *>' requested here
//         _M_range_initialize(__l.begin(), __l.end(),
//         ^
// input_line_11:4:5: note: in instantiation of member function 'std::vector<int, std::allocator<int> >::vector' requested here
//     {1, 2, 3}, // A: B C D
//     ^
// In file included from input_line_5:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/include/xeus/xinterpreter.hpp:13:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/functional:62:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/vector:66:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_uninitialized.h:137:72: error: no member named 'value' in 'std::is_constructible<int, const int &>'
//       static_assert(is_constructible<_ValueType2, decltype(*__first)>::value,
//                     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_uninitialized.h:325:19: note: in instantiation of function template specialization 'std::uninitialized_copy<const int *, int *>' requested here
//     { return std::uninitialized_copy(__first, __last, __result); }
//                   ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:1585:11: note: in instantiation of function template specialization 'std::__uninitialized_copy_a<const int *, int *, int>' requested here
//             std::__uninitialized_copy_a(__first, __last,
//                  ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:629:2: note: in instantiation of function template specialization 'std::vector<int, std::allocator<int> >::_M_range_initialize<const int *>' requested here
//         _M_range_initialize(__l.begin(), __l.end(),
//         ^
// input_line_11:4:5: note: in instantiation of member function 'std::vector<int, std::allocator<int> >::vector' requested here
//     {1, 2, 3}, // A: B C D
//     ^
// In file included from input_line_1:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:116:31: error: no member named 'value' in 'std::is_lvalue_reference<std::vector<int, std::allocator<int> > >'
//     : public conditional<_B1::value, _B1, _B2>::type
//                          ~~~~~^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:528:14: note: in instantiation of template class 'std::__or_<std::is_lvalue_reference<std::vector<int, std::allocator<int> > >, std::is_rvalue_reference<std::vector<int, std::allocator<int> > > >' requested here
//     : public __or_<is_lvalue_reference<_Tp>,
// no member named 'value' in 'std::is_lvalue_reference<std::vector<int, std::allocator<int> > >'
//     : public conditional<_B1::value, _B1, _B2>::type
//                          ~~~~~^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:528:14: note: in instantiation of template class 'std::__or_<std::is_lvalue_reference<std::vector<int, std::allocator<int> > >, std::is_rvalue_reference<std::vector<int, std::allocator<int> > > >' requested here
//     : public __or_<is_lvalue_reference<_Tp>,
//              ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:121:26: note: in instantiation of template class 'std::is_reference<std::vector<int, std::allocator<int> > >' requested here
//     : public conditional<_B1::value, _B1, __or_<_B2, _B3, _Bn...>>::type
//                          ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:206             ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:121:26: note: in instantiation of template class 'std::is_reference<std::vector<int, std::allocator<int> > >' requested here
//     : public conditional<_B1::value, _B1, __or_<_B2, _B3, _Bn...>>::type
//                          ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:206:24: note: in instantiation of template class 'std::__or_<std::is_reference<std::vector<int, std::allocator<int> > >, std::is_function<std::vector<int, std::allocator<int> > >, std::is_void<std::vector<int, std::allocator<int> > >, std::__is_array_unknown_bounds<std::vector<int, std::allocator<int> > > >' requested here
//     constexpr typename __or_<
//                        ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:909:21: note:24: note: in instantiation of template class 'std::__or_<std::is_reference<std::vector<int, std::allocator<int> > >, std::is_function<std::vector<int, std::allocator<int> > >, std::is_void<std::vector<int, std::allocator<int> > >, std::__is_array_unknown_bounds<std::vector<int, std::allocator<int> > > >' requested here
//     constexpr typename __or_<
//                        ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:909:21: note: while substituting deduced template arguments into function template '__is_complete_or_unbounded' [with _TypeIdentity = std::__type_identity<std::vector<int, std::allocator<int> > >, _NestedType = (no value)]
//       static_assert(std::__is_complete_or_unbounded(__type_identity<_Tp>{}),
//                     ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_uninitialized.h:137:21: note: in instantiation of template class 'std::is_constructible<std::vector<int, std::allocator<int> >, const std::vector<int, std::allocator<int> > &>' requested here
//       static_assert(is_constructible<_ValueType2, decltype(*__first)>::value,: while substituting deduced template arguments into function template '__is_complete_or_unbounded' [with _TypeIdentity = std::__type_identity<std::vector<int, std::allocator<int> > >, _NestedType = (no value)]
//       static_assert(std::__is_complete_or_unbounded(__type_identity<_Tp>{}),
//                     ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_uninitialized.h:137:21: note: in instantiation of template class 'std::is_constructible<std::vector<int, std::allocator<int> >, const std::vector<int, std::allocator<int> > &>' requested here
//       static_assert(is_constructible<_ValueType2, decltype(*__first)>::value,
//                     ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_uninitialized.h:325:19: note: in instantiation of function template specialization 'std::uninitialized_copy<const std::vector<int, std::allocator<int> > *, std::vector<int, std::allocator<int> > *>' requested here
//     { return std::uninitialized_copy(__first, __last, __result); }
//                   ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:1585
//                     ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_uninitialized.h:325:19: note: in instantiation of function template specialization 'std::uninitialized_copy<const std::vector<int, std::allocator<int> > *, std::vector<int, std::allocator<int> > *>' requested here
//     { return std::uninitialized_copy(__first, __last, __result); }
//                   ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:1585:11: note: in instantiation of function template specialization 'std::__uninitialized_copy_a<const std::vector<int, std::allocator<int> > *, std::vector<int, std::allocator<int> > *, std::vector<int, std::allocator<int> > >' requested here
//             std::__uninitialized_copy_a(__first, __last,
//                  ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:629:2: note: in instantiation of function template specialization 'std::vector<std::vector<int, std::allocator<int> >, std::allocator<std::vector<int, std::allocator<int> > > >::_M_range_initialize<const std::vector<int, std::allocator<int> > *>' requested here
//         _M_range_initialize(__l.begin(), __l.end(),
//         ^
// input_line_11::11: note: in instantiation of function template specialization 'std::__uninitialized_copy_a<const std::vector<int, std::allocator<int> > *, std::vector<int, std::allocator<int> > *, std::vector<int, std::allocator<int> > >' requested here
//             std::__uninitialized_copy_a(__first, __last,
//                  ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:629:2: note: in instantiation of function template specialization 'std::vector<std::vector<int, std::allocator<int> >, std::allocator<std::vector<int, std::allocator<int> > > >::_M_range_initialize<const std::vector<int, std::allocator<int> > *>' requested here
//         _M_range_initialize(__l.begin(), __l.end(),
//         ^
// input_line_11:3:41: note: in instantiation of member function 'std::vector<std::vector<int, std::allocator<int> >, std::allocator<std::vector<int, std::allocator<int> > > >::vector' requested here
// std::vector<std::vector<int>> adjList = {
//                                         ^
// In file included from input_line_5:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/include/xeus/xinterpreter.hpp3:41: note: in instantiation of member function 'std::vector<std::vector<int, std::allocator<int> >, std::allocator<std::vector<int, std::allocator<int> > > >::vector' requested here
// std::vector<std::vector<int>> adjList = {
//                                         ^
// In file included from input_line_5:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/include/xeus/xinterpreter.hpp:13:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/functional:62:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/vector:66:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_uninitialized.h:137:72: error: no member named 'value' in 'std::is_constructible<std::vector<int, std::allocator<int> >, const std::vector<int, std::allocator<int> > &>'
//       static_assert(is_constructible<_ValueType2, decltype(*__first)>::value,
//                     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_uninitialized.h:325:13:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/functional:62:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/vector:66:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_uninitialized.h:137:72: error: no member named 'value' in 'std::is_constructible<std::vector<int, std::allocator<int> >, const std::vector<int, std::allocator<int> > &>'
//       static_assert(is_constructible<_ValueType2, decltype(*__first)>::value,
//                     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_uninitialized.h:325:19: note: in instantiation of function template specialization 'std::uninitialized_copy<const std::vector<int, std::allocator<int> > *, std::vector<int, std::allocator<int> > *>' requested here
//     { return std::uninitialized_copy(__first, __last, __result); }
//                   ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:1585:11: note: in instantiation of function template specialization 'std::__uninitialized_copy_a<const std::vector<int, std::allocator<int> > *, std::vector<int, std::allocator<int> > *, std::vector<int, std::allocator<int> > >' requested here
//             std::__uninitialized_copy_a(__first, __last,
//                  ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:629:2::19: note: in instantiation of function template specialization 'std::uninitialized_copy<const std::vector<int, std::allocator<int> > *, std::vector<int, std::allocator<int> > *>' requested here
//     { return std::uninitialized_copy(__first, __last, __result); }
//                   ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:1585:11: note: in instantiation of function template specialization 'std::__uninitialized_copy_a<const std::vector<int, std::allocator<int> > *, std::vector<int, std::allocator<int> > *, std::vector<int, std::allocator<int> > >' requested here
//             std::__uninitialized_copy_a(__first, __last,
//                  ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:629:2: note: in instantiation of function template specialization 'std::vector<std::vector<int, std::allocator<int> >, std::allocator<std::vector<int, std::allocator<int> > > >::_M_range_initialize<const std::vector<int, std::allocator<int> > *>' requested here
//         _M_range_initialize(__l.begin(), __l.end(),
//         ^
// input_line_11:3:41: note: in instantiation of member function 'std::vector<std::vector<int, std::allocator<int> >, std::allocator<std::vector<int, std::allocator<int> > > >::vector' requested here
// std::vector<std::vector<int>> adjList = {
//                                         ^
// In file included from input_line_1:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:121:31: error: no member named 'value' in 'std::is_void<std::vector<int, std::allocator<int> > >'
//     : public conditional<_B1::value, _B1, __or_<_B2, _B3, _Bn...>>::type
//                          ~~~~~^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:819:19: note: in instantiation of template class 'std::__or_<std::is_void<std::vector<int, std::allocator<int> > >, std::__is_array_unknown_bounds<std::vector<int, std::allocator<int> > >, std::is_function<std::vector<int, std::allocator<int> > > >' requested here
//            bool = __or_<is_void<_Tp>,
//                   ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:842:14: note: in instantiation of default argument for '__is_destructible_safe<std::vector<int, std::allocator<int> > >' required here
//     : public __is_destructible_safe<_Tp>::type
//              ^~~~~~~~~~~~~~~~~~~~~~~~~~~
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_construct.h:177:21: note: in instantiation of template class 'std::is_destructible<std::vector<int, std::allocator<int> > >' requested here
//       static_assert(is_destructible<_Value_type>::value,
//                     ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/alloc_traits.h:842:7: note: in instantiation of function template specialization 'std::_Destroy<std::vector<int, std::allocator<int> > *>' requested here
//       _Destroy(__first, __last);
//       ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:680:7: note: in instantiation of function template specialization 'std::_Destroy<std::vector<int, std::allocator<int> > *, std::vector<int, std::allocator<int> > >' requested here
//         std::_Destroy(this->_M_impl._M_start, this->_M_impl._M_finish,
//              ^
// input_line_11:3:31: note: in instantiation of member function 'std::vector<std::vector<int, std::allocator<int> >, std::allocator<std::vector<int, std::allocator<int> > > >::~vector' requested here
// std::vector<std::vector<int>> adjList = {
//                               ^
// In file included from input_line_5:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/include/xeus/xinterpreter.hpp:17:
//  note: in instantiation of function template specialization 'std::vector<std::vector<int, std::allocator<int> >, std::allocator<std::vector<int, std::allocator<int> > > >::_M_range_initialize<const std::vector<int, std::allocator<int> > *>' requested here
//         _M_range_initialize(__l.begin(), __l.end(),
//         ^
// input_line_11:3:41: note: in instantiation of member function 'std::vector<std::vector<int, std::allocator<int> >, std::allocator<std::vector<int, std::allocator<int> > > >::vector' requested here
// std::vector<std::vector<int>> adjList = {
//                                         ^
// In file included from input_line_1:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:121:31: error: no member named 'value' in 'std::is_void<std::vector<int, std::allocator<int> > >'
//     : public conditional<_B1::value, _B1, __or_<_B2, _B3, _Bn...>>::type
//                          ~~~~~^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:819:19: note: in instantiation of template class 'std::__or_<std::is_void<std::vector<int, std::allocator<int> > >, std::__is_array_unknown_bounds<std::vector<int, std::allocator<int> > >, std::is_function<std::vector<int, std::allocator<int> > > >' requested here
//            bool = __or_<is_void<_Tp>,
//                   ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:842:14: note: in instantiation of default argument for '__is_destructible_safe<std::vector<int, std::allocator<int> > >' required here
//     : public __is_destructible_safe<_Tp>::type
//              ^~~~~~~~~~~~~~~~~~~~~~~~~~~
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_construct.h:177:21: note: in instantiation of template class 'std::is_destructible<std::vector<int, std::allocator<int> > >' requested here
//       static_assert(is_destructible<_Value_type>::value,
//                     ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/alloc_traits.h:842:7: note: in instantiation of function template specialization 'std::_Destroy<std::vector<int, std::allocator<int> > *>' requested here
//       _Destroy(__first, __last);
//       ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:680:7: note: in instantiation of function template specialization 'std::_Destroy<std::vector<int, std::allocator<int> > *, std::vector<int, std::allocator<int> > >' requested here
//         std::_Destroy(this->_M_impl._M_start, this->_M_impl._M_finish,
//              ^
// input_line_11:3:31: note: in instantiation of member function 'std::vector<std::vector<int, std::allocator<int> >, std::allocator<std::vector<int, std::allocator<int> > > >::~vector' requested here
// std::vector<std::vector<int>> adjList = {
//                               ^
// In file included from input_line_5:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/include/xeus/xinterpreter.hpp:17:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/include/xeus/xcomm.hpp:19:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/include/nlohmann/json.hpp:34:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/include/nlohmann/adl_serializer.hpp:14:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/include/nlohmann/detail/conversions/from_json.hpp:27:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/include/nlohmann/detail/meta/std_fs.hpp:22:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/filesystem:45:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/fs_path.h:39:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/iomanip:45:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/quoted_string.h:38:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/sstream:38:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/istream:39:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:609:8: error: no member named 'setstate' in 'std::basic_ostream<char>'
//         __out.setstate(ios_base::badbit);
//         ~~~~~ ^
// input_line_11:17:11: note: in instantiation of function template specialization 'std::operator<<<std::char_traits<char> >' requested here
// std::cout << "Adjacency List:\n";
//           ^
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/include/xeus/xcomm.hpp:19:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/include/nlohmann/json.hpp:34:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/include/nlohmann/adl_serializer.hpp:14:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/include/nlohmann/detail/conversions/from_json.hpp:27:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/include/nlohmann/detail/meta/std_fs.hpp:22:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/filesystem:45:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/fs_path.h:39:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/iomanip:45:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/quoted_string.h:38:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/sstream:38:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/istream:39:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:609:8: error: no member named 'setstate' in 'std::basic_ostream<char>'
//         __out.setstate(ios_base::badbit);
//         ~~~~~ ^
// input_line_11:17:11: note: in instantiation of function template specialization 'std::operator<<<std::char_traits<char> >' requested here
// std::cout << "Adjacency List:\n";
//           ^
// Interpreter Error:

// %% [markdown]
// ## Representing a Directed Graph
//
// The graphs above are undirected. But directed graphs can be represented similarly.  In the matrix representation, a directed edge from node A to node B would be represented by a 1 in the row for A and the column for B, but a 0 in the row for B and the column for A.

// %% [markdown]
// ### Example Directed Graph (visual)
//
// Below is a small directed graph shown with arrows. The C++ code cell that follows constructs the same graph as an adjacency list and an adjacency matrix.
//
// <div style="text-align:center">
// <img src="docs/images/Lab12/directed.svg" style="max-width:100%;height:auto;"/>
// </div>

// %%
int n = 4;

// Adjacency list for a directed graph:
// A -> B, C; B -> C; C -> D; D -> (none)
std::vector<std::vector<int>> adjList = {
    {1, 2}, // A -> B, C
    {2},    // B -> C
    {3},    // C -> D
    {}      // D -> none
};

// Adjacency matrix for the same directed graph
//   A B C D
std::vector<std::vector<int>> adjMatrix = {
    {0,1,1,0}, // A
    {0,0,1,0}, // B
    {0,0,0,1}, // C
    {0,0,0,0}  // D
};

// Print adjacency list (with letter labels)
std::cout << "Directed Adjacency List:\n";
for (int i = 0; i < n; ++i) {
    std::cout << char('A' + i) << ": ";
    for (int v : adjList[i])
        std::cout << char('A' + v) << ' ';
    std::cout << '\n';
}

// Print adjacency matrix
std::cout << "\nDirected Adjacency Matrix:\n";
std::cout << "  ";
for (int i = 0; i < n; ++i) 
    std::cout << char('A' + i) << ' ';
std::cout << '\n';

for (int i = 0; i < n; ++i) {
    std::cout << char('A' + i) << ' ';
    for (int j = 0; j < n; ++j) std::cout << adjMatrix[i][j] << ' ';
    std::cout << '\n';
}
// Out:
// Directed Adjacency List:
// A: B C
// B: C
// C: D
// D:
//
// Directed Adjacency Matrix:
//   A B C D
// A 0 1 1 0
// B 0 0 1 0
// C 0 0 0 1
// D 0 0 0 0
