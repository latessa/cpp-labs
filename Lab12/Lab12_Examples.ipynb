// %% [markdown]
// # Lab 12 Examples (Dijkstra's Single Source Shortest Path)

// %% [markdown]
// Click Shift+Enter in each code cell to run the code. Be sure to start with the `#include` directives to load the required libraries.

// %%
// For Lab 12, we are limited to using only the following #include directives:

#include <iostream>
#include <algorithm>
#include <cmath>
#include <queue>
#include <string>
#include <utility>
#include <vector>

// %% [markdown]
// ## Overview
//
// In today's lab, we will implement Dijkstra's single source shortest path algorithm. This algorithm finds the shortest paths from a source node to all other nodes in a weighted graph with non-negative edge weights. The graph can be directed or undirected, but it must not contain negative weight edges.

// %% [markdown]
// ## Representing an Undirected Graph
//
// Graphs are structures made up of nodes (or vertices) connected by edges. They can be represented in code using various methods, such as adjacency matrices or adjacency lists. Below is a simple undirected graph shown visually using an inline SVG; the C++ code cell that follows constructs the same graph as an adjacency list and an adjacency matrix.
//
// <div style="text-align:center">
// <img src="https://latessa.github.io/cpp-labs/images/Lab12/undirected.svg" alt="Undirected graph (A–D)" style="width:70%;height:auto;"/>
// </div>

// %%
int n = 4;

std::vector<std::vector<int>> adjList = {
    {1, 2, 3}, // A: B C D
    {0, 2},    // B: A C
    {0, 1, 3}, // C: A B D
    {0, 2}     // D: A C
};

std::vector<std::vector<int>> adjMatrix = {
//   A  B  C  D
    {0, 1, 1, 1}, // A
    {1, 0, 1, 0}, // B
    {1, 1, 0, 1}, // C
    {1, 0, 1, 0}  // D
};

// Print adjacency list (with letter labels)
std::cout << "Adjacency List:\n";
for (int i = 0; i < n; ++i) {
    std::cout << char('A' + i) << ": ";
    for (int v : adjList[i]) 
        std::cout << char('A' + v) << ' ';
    std::cout << '\n';
}

// Print adjacency matrix
std::cout << "\nAdjacency Matrix:\n";
std::cout << "  ";
for (int i = 0; i < n; ++i) 
    std::cout << char('A' + i) << ' ';
std::cout << '\n';

for (int i = 0; i < n; ++i) {
    std::cout << char('A' + i) << ' ';
    for (int j = 0; j < n; ++j) std::cout << adjMatrix[i][j] << ' ';
        std::cout << '\n';
}
// Out:
// Adjacency List:
// A: B C D
// B: A C
// C: A B D
// D: A C
//
// Adjacency Matrix:
//   A B C D
// A 0 1 1 1
// B 1 0 1 0
// C 1 1 0 1
// D 1 0 1 0

// %% [markdown]
// ## Representing a Directed Graph
//
// The graphs above are undirected. But directed graphs can be represented similarly.  In the matrix representation, a directed edge from node A to node B would be represented by a 1 in the row for A and the column for B, but a 0 in the row for B and the column for A.

// %% [markdown]
// <div style="text-align:center">
// <img src="https://latessa.github.io/cpp-labs/images/Lab12/directed.svg" alt="Directed graph (A→B, A→C, B→C)" style="width:70%;height:auto;"/>
// </div>

// %%
int n = 4;

// Adjacency list for a directed graph:
// A -> B, C; B -> C; C -> D; D -> (none)
std::vector<std::vector<int>> adjList = {
    {1, 2}, // A -> B, C
    {2},    // B -> C
    {3},    // C -> D
    {}      // D -> none
};

// Adjacency matrix for the same directed graph
//   A B C D
std::vector<std::vector<int>> adjMatrix = {
    {0,1,1,0}, // A
    {0,0,1,0}, // B
    {0,0,0,1}, // C
    {0,0,0,0}  // D
};

// Print adjacency list (with letter labels)
std::cout << "Directed Adjacency List:\n";
for (int i = 0; i < n; ++i) {
    std::cout << char('A' + i) << ": ";
    for (int v : adjList[i])
        std::cout << char('A' + v) << ' ';
    std::cout << '\n';
}

// Print adjacency matrix
std::cout << "\nDirected Adjacency Matrix:\n";
std::cout << "  ";
for (int i = 0; i < n; ++i) 
    std::cout << char('A' + i) << ' ';
std::cout << '\n';

for (int i = 0; i < n; ++i) {
    std::cout << char('A' + i) << ' ';
    for (int j = 0; j < n; ++j) std::cout << adjMatrix[i][j] << ' ';
    std::cout << '\n';
}
// Out:
// Directed Adjacency List:
// A: B C
// B: C
// C: D
// D:
//
// Directed Adjacency Matrix:
//   A B C D
// A 0 1 1 0
// B 0 0 1 0
// C 0 0 0 1
// D 0 0 0 0

// %% [markdown]
// ### Representing a Weighted Graph
//
// In a weighted graph, each edge has an associated weight (or cost).
//
// In the adjacency matrix representation, instead of using 1s and 0s to indicate the presence or absence of edges, we use the actual weights. If there is no edge between two nodes, we can use a special value (like infinity) to indicate that.
//
// In the adjacency list representation, each entry in the list can be a pair consisting of the neighboring node and the weight of the edge connecting them. The C++ standard library provides the `std::pair` container class, which is useful for key-value pairs or data with distinctly two parts such as a destination node and edge weight.

// %% [markdown]
// ## Weighted Undirected Graph (with positive edge weights)
//
// <div style="text-align:center">
// <img src="https://latessa.github.io/cpp-labs/images/Lab12/undirected_weighted.svg" alt="Weighted undirected graph (A–D)" style="width:70%;height:auto;"/>
// </div>

// %% [markdown]
// ### Exploring the STL Pair Type

// %%
// Introducing the use of the PAIR type

// make_pair deduces the types automatically
auto p = std::make_pair(2, 5.54);
std::cout << "First: " << p.first << ", Second: " << p.second << '\n';

// Explicitly specifying the PAIR type
std::pair<double, int> p2;
p2.first = 12.45;
p2.second = 20;
std::cout << "First: " << p2.first << ", Second: " << p2.second << '\n';

std::vector<std::pair<int, double>> test;
test.push_back(std::make_pair(1, 2.5));

// Using initializer list to create a pair
test.push_back({3, 4.5});
for (const auto& pr : test) {
    std::cout << "First: " << pr.first << ", Second: " << pr.second << '\n';
}
// Out:
// In file included from input_line_5:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/include/xeus/xinterpreter.hpp:13:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/functional:54:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:38:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/utility:70:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:392:36: error: no member named 'value' in 'std::__and_<std::is_copy_assignable<int>, std::is_copy_assignable<int> >'
//                        is_copy_assignable<_T2>>::value,
//                        ~~~~~~~~~~~~~~~~~~~~~~~~~~^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:567:5: note: in instantiation of template class 'std::pair<int, int>' requested here
//     make_pair(_T1&& __x, _T2&& __y)
//     ^
// input_line_12:4:15: note: in instantiation of function template specialization 'std::make_pair<int, double>' requested here
// auto p = std::make_pair(2, 5.54);
//               ^
// In file included from input_line_5:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/include/xeus/xinterpreter.hpp:13:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/functional:54:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:38:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/utility:70:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:403:36: error: no member named 'value' in 'std::__and_<std::is_move_assignable<int>, std::is_move_assignable<int> >'
//                        is_move_assignable<_T2>>::value,
//                        ~~~~~~~~~~~~~~~~~~~~~~~~~~^
// In file included from input_line_1:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:139:31: error: no member named 'value' in 'std::is_constructible<int, const int &>'
//     : public conditional<_B1::value, _B2, _B1>::type
//                          ~~~~~^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:106:9: note: in instantiation of template class 'std::__and_<std::is_constructible<int, const int &>, std::is_constructible<int, const int &> >' requested here
//         return __and_<is_constructible<_T1, const _U1&>,
//                ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:262:7: note: in instantiation of function template specialization 'std::_PCC<true, int, int>::_ConstructiblePair<int, int>' requested here
//                            _ConstructiblePair<_U1, _U2>()
//                            ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:266:17: note: while substituting prior template arguments into non-type template parameter [with _U1 = int, _U2 = int]
//       constexpr pair(const _T1& __a, const _T2& __b)
//                 ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:572:14: note: while substituting deduced template arguments into function template 'pair' [with _U1 = (no value), _U2 = (no value), $2 = (no value)]
//       return __pair_type(std::forward<_T1>(__x), std::forward<_T2>(__y));
//              ^
// input_line_12:4:15: note: in instantiation of function template specialization 'std::make_pair<int, double>' requested here
// auto p = std::make_pair(2, 5.54);
//               ^
// In file included from input_line_5:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/include/xeus/xinterpreter.hpp:13:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/functional:54:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:38:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/utility:70:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:114:43: error: no member named 'value' in 'std::__and_<std::is_convertible<const int &, int>, std::is_convertible<const int &, int> >'
//                       is_convertible<const _U2&, _T2>>::value;
//                       ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:264:7: note: in instantiation of function template specialization 'std::_PCC<true, int, int>::_ImplicitlyConvertiblePair<int, int>' requested here
//                            _ImplicitlyConvertiblePair<_U1, _U2>(),
//                            ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:266:17: note: while substituting prior template arguments into non-type template parameter [with _U1 = int, _U2 = int]
//       constexpr pair(const _T1& __a, const _T2& __b)
//                 ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:572:14: note: while substituting deduced template arguments into function template 'pair' [with _U1 = (no value), _U2 = (no value), $2 = (no value)]
//       return __pair_type(std::forward<_T1>(__x), std::forward<_T2>(__y));
//              ^
// input_line_12:4:15: note: in instantiation of function template specialization 'std::make_pair<int, double>' requested here
// auto p = std::make_pair(2, 5.54);
//               ^
// In file included from input_line_1:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:144:31: error: no member named 'value' in 'std::is_constructible<int, int &&>'
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//                          ~~~~~^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:153:9: note: in instantiation of template class 'std::__and_<std::is_constructible<int, int &&>, std::is_constructible<int, const int &&>, std::__and_<std::is_convertible<int &&, int>, std::is_convertible<const int &, int> > >' requested here
//         return __and_<is_constructible<_T1, _U1&&>,
//                ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:320:7: note: in instantiation of function template specialization 'std::_PCC<true, int, int>::_MoveCopyPair<true, int, int>' requested here
//                            _MoveCopyPair<true, _U1, _T2>(),
//                            ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:322:18: note: while substituting prior template arguments into non-type template parameter [with _U1 = int]
//        constexpr pair(_U1&& __x, const _T2& __y)
//                  ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:572:14: note: while substituting deduced template arguments into function template 'pair' [with _U1 = int, $1 = (no value)]
//       return __pair_type(std::forward<_T1>(__x), std::forward<_T2>(__y));
//              ^
// input_line_12:4:15: note: in instantiation of function template specialization 'std::make_pair<int, double>' requested here
// auto p = std::make_pair(2, 5.54);
//               ^
// In file included from input_line_1:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:144:31: error: no member named 'value' in 'std::is_constructible<int, int &&>'
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//                          ~~~~~^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:153:9: note: in instantiation of template class 'std::__and_<std::is_constructible<int, int &&>, std::is_constructible<int, const int &&>, std::__not_<std::__and_<std::is_convertible<int &&, int>, std::is_convertible<const int &, int> > > >' requested here
//         return __and_<is_constructible<_T1, _U1&&>,
//                ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:327:7: note: in instantiation of function template specialization 'std::_PCC<true, int, int>::_MoveCopyPair<false, int, int>' requested here
//                            _MoveCopyPair<false, _U1, _T2>(),
//                            ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:329:27: note: while substituting prior template arguments into non-type template parameter [with _U1 = int]
//        explicit constexpr pair(_U1&& __x, const _T2& __y)
//                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:572:14: note: while substituting deduced template arguments into function template 'pair' [with _U1 = int, $1 = (no value)]
//       return __pair_type(std::forward<_T1>(__x), std::forward<_T2>(__y));
//              ^
// input_line_12:4:15: note: in instantiation of function template specialization 'std::make_pair<int, double>' requested here
// auto p = std::make_pair(2, 5.54);
//               ^
// In file included from input_line_1:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:144:31: error: no member named 'value' in 'std::is_constructible<int, const int &>'
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//                          ~~~~~^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:139:9: note: in instantiation of template class 'std::__and_<std::is_constructible<int, const int &>, std::is_constructible<int, double &&>, std::__and_<std::is_convertible<const int &, int>, std::is_convertible<double &&, int> > >' requested here
//         return __and_<is_constructible<_T1, const _U1&>,
//                ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:334:7: note: in instantiation of function template specialization 'std::_PCC<true, int, int>::_CopyMovePair<true, int, double>' requested here
//                            _CopyMovePair<true, _T1, _U2>(),
//                            ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:336:18: note: while substituting prior template arguments into non-type template parameter [with _U2 = double]
//        constexpr pair(const _T1& __x, _U2&& __y)
//                  ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:572:14: note: while substituting deduced template arguments into function template 'pair' [with _U2 = double, $1 = (no value)]
//       return __pair_type(std::forward<_T1>(__x), std::forward<_T2>(__y));
//              ^
// input_line_12:4:15: note: in instantiation of function template specialization 'std::make_pair<int, double>' requested here
// auto p = std::make_pair(2, 5.54);
//               ^
// In file included from input_line_1:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:144:31: error: no member named 'value' in 'std::is_constructible<int, const int &>'
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//                          ~~~~~^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:139:9: note: in instantiation of template class 'std::__and_<std::is_constructible<int, const int &>, std::is_constructible<int, double &&>, std::__not_<std::__and_<std::is_convertible<const int &, int>, std::is_convertible<double &&, int> > > >' requested here
//         return __and_<is_constructible<_T1, const _U1&>,
//                ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:341:7: note: in instantiation of function template specialization 'std::_PCC<true, int, int>::_CopyMovePair<false, int, double>' requested here
//                            _CopyMovePair<false, _T1, _U2>(),
//                            ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:343:17: note: while substituting prior template arguments into non-type template parameter [with _U2 = double]
//        explicit pair(const _T1& __x, _U2&& __y)
//                 ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:572:14: note: while substituting deduced template arguments into function template 'pair' [with _U2 = double, $1 = (no value)]
//       return __pair_type(std::forward<_T1>(__x), std::forward<_T2>(__y));
//              ^
// input_line_12:4:15: note: in instantiation of function template specialization 'std::make_pair<int, double>' requested here
// auto p = std::make_pair(2, 5.54);
//               ^
// In file included from input_line_1:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:139:31: error: no member named 'value' in 'std::is_constructible<int, int &&>'
//     : public conditional<_B1::value, _B2, _B1>::type
//                          ~~~~~^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:120:9: note: in instantiation of template class 'std::__and_<std::is_constructible<int, int &&>, std::is_constructible<int, double &&> >' requested here
//         return __and_<is_constructible<_T1, _U1&&>,
//                ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:348:7: note: in instantiation of function template specialization 'std::_PCC<true, int, int>::_MoveConstructiblePair<int, double>' requested here
//                            _MoveConstructiblePair<_U1, _U2>()
//                            ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:352:12: note: while substituting prior template arguments into non-type template parameter [with _U1 = int, _U2 = double]
//         constexpr pair(_U1&& __x, _U2&& __y)
//                   ^~~~~~~~~~~~~~~~~~~~~~~~~~
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:572:14: note: while substituting deduced template arguments into function template 'pair' [with _U1 = int, _U2 = double, $2 = (no value)]
//       return __pair_type(std::forward<_T1>(__x), std::forward<_T2>(__y));
//              ^
// input_line_12:4:15: note: in instantiation of function template specialization 'std::make_pair<int, double>' requested here
// auto p = std::make_pair(2, 5.54);
//               ^
// In file included from input_line_5:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/include/xeus/xinterpreter.hpp:13:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/functional:54:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:38:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/utility:70:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:128:38: error: no member named 'value' in 'std::__and_<std::is_convertible<int &&, int>, std::is_convertible<double &&, int> >'
//                       is_convertible<_U2&&, _T2>>::value;
//                       ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:350:7: note: in instantiation of function template specialization 'std::_PCC<true, int, int>::_ImplicitlyMoveConvertiblePair<int, double>' requested here
//                            _ImplicitlyMoveConvertiblePair<_U1, _U2>(),
//                            ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:352:12: note: while substituting prior template arguments into non-type template parameter [with _U1 = int, _U2 = double]
//         constexpr pair(_U1&& __x, _U2&& __y)
//                   ^~~~~~~~~~~~~~~~~~~~~~~~~~
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:572:14: note: while substituting deduced template arguments into function template 'pair' [with _U1 = int, _U2 = double, $2 = (no value)]
//       return __pair_type(std::forward<_T1>(__x), std::forward<_T2>(__y));
//              ^
// input_line_12:4:15: note: in instantiation of function template specialization 'std::make_pair<int, double>' requested here
// auto p = std::make_pair(2, 5.54);
//               ^
// In file included from input_line_5:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/include/xeus/xinterpreter.hpp:13:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/functional:54:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:38:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/utility:70:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:572:14: error: no matching constructor for initialization of '__pair_type' (aka 'pair<int, int>')
//       return __pair_type(std::forward<_T1>(__x), std::forward<_T2>(__y));
//              ^           ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
// input_line_12:4:15: note: in instantiation of function template specialization 'std::make_pair<int, double>' requested here
// auto p = std::make_pair(2, 5.54);
//               ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:266:17: note: candidate template ignored: substitution failure [with _U1 = int, _U2 = int]: non-type template argument is not a constant expression
//       constexpr pair(const _T1& __a, const _T2& __b)
//                 ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:276:26: note: candidate template ignored: substitution failure [with _U1 = int, _U2 = int]: no matching function for call to '_ConstructiblePair'
//       explicit constexpr pair(const _T1& __a, const _T2& __b)
//                          ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:322:18: note: candidate template ignored: substitution failure [with _U1 = int]: non-type template argument is not a constant expression
//        constexpr pair(_U1&& __x, const _T2& __y)
//                  ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:329:27: note: candidate template ignored: substitution failure [with _U1 = int]: non-type template argument is not a constant expression
//        explicit constexpr pair(_U1&& __x, const _T2& __y)
//                           ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:336:18: note: candidate template ignored: substitution failure [with _U2 = double]: non-type template argument is not a constant expression
//        constexpr pair(const _T1& __x, _U2&& __y)
//                  ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:343:17: note: candidate template ignored: substitution failure [with _U2 = double]: non-type template argument is not a constant expression
//        explicit pair(const _T1& __x, _U2&& __y)
//                 ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:352:12: note: candidate template ignored: substitution failure [with _U1 = int, _U2 = double]: non-type template argument is not a constant expression
//         constexpr pair(_U1&& __x, _U2&& __y)
//                   ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:361:21: note: candidate template ignored: substitution failure [with _U1 = int, _U2 = double]: no matching function for call to '_MoveConstructiblePair'
//         explicit constexpr pair(_U1&& __x, _U2&& __y)
//                            ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:232:26: note: candidate constructor template not viable: requires 0 arguments, but 2 were provided
//       _GLIBCXX_CONSTEXPR pair()
//                          ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:245:26: note: candidate constructor template not viable: requires 0 arguments, but 2 were provided
//       explicit constexpr pair()
//                          ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:300:19: note: candidate constructor template not viable: requires single argument '__p', but 2 arguments were provided
//         constexpr pair(const pair<_U1, _U2>& __p)
//                   ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:309:21: note: candidate constructor template not viable: requires single argument '__p', but 2 arguments were provided
//         explicit constexpr pair(const pair<_U1, _U2>& __p)
//                            ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:371:12: note: candidate constructor template not viable: requires single argument '__p', but 2 arguments were provided
//         constexpr pair(pair<_U1, _U2>&& __p)
//                   ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:381:21: note: candidate constructor template not viable: requires single argument '__p', but 2 arguments were provided
//         explicit constexpr pair(pair<_U1, _U2>&& __p)
//                            ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:387:9: note: candidate constructor template not viable: requires 3 arguments, but 2 were provided
//         pair(piecewise_construct_t, tuple<_Args1...>, tuple<_Args2...>);
//         ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:452:9: note: candidate constructor template not viable: requires 4 arguments, but 2 were provided
//         pair(tuple<_Args1...>&, tuple<_Args2...>&,
//         ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:314:17: note: candidate constructor not viable: requires 1 argument, but 2 were provided
//       constexpr pair(const pair&) = default;    ///< Copy constructor
//                 ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:315:17: note: candidate constructor not viable: requires 1 argument, but 2 were provided
//       constexpr pair(pair&&) = default;         ///< Move constructor
//                 ^
// In file included from input_line_1:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:1076:58: error: no member named 'value' in 'std::__is_referenceable<double, void>'
//   template<typename _Tp, bool = __is_referenceable<_Tp>::value>
//                                 ~~~~~~~~~~~~~~~~~~~~~~~~~^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:1091:14: note: in instantiation of default argument for '__is_copy_assignable_impl<double>' required here
//     : public __is_copy_assignable_impl<_Tp>::type
//              ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:139:26: note: in instantiation of template class 'std::is_copy_assignable<double>' requested here
//     : public conditional<_B1::value, _B2, _B1>::type
//                          ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:391:3: note: in instantiation of template class 'std::__and_<std::is_copy_assignable<double>, std::is_copy_assignable<int> >' requested here
//                 __and_<is_copy_assignable<_T1>,
//                 ^
// input_line_12:7:24: note: in instantiation of template class 'std::pair<double, int>' requested here
// std::pair<double, int> p2;
//                        ^
// In file included from input_line_1:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:116:31: error: no member named 'value' in 'std::is_lvalue_reference<double>'
//     : public conditional<_B1::value, _B1, _B2>::type
//                          ~~~~~^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:528:14: note: in instantiation of template class 'std::__or_<std::is_lvalue_reference<double>, std::is_rvalue_reference<double> >' requested here
//     : public __or_<is_lvalue_reference<_Tp>,
//              ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:121:26: note: in instantiation of template class 'std::is_reference<double>' requested here
//     : public conditional<_B1::value, _B1, __or_<_B2, _B3, _Bn...>>::type
//                          ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:206:24: note: in instantiation of template class 'std::__or_<std::is_reference<double>, std::is_function<double>, std::is_void<double>, std::__is_array_unknown_bounds<double> >' requested here
//     constexpr typename __or_<
//                        ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:1093:21: note: while substituting deduced template arguments into function template '__is_complete_or_unbounded' [with _TypeIdentity = std::__type_identity<double>, _NestedType = (no value)]
//       static_assert(std::__is_complete_or_unbounded(__type_identity<_Tp>{}),
//                     ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:139:26: note: in instantiation of template class 'std::is_copy_assignable<double>' requested here
//     : public conditional<_B1::value, _B2, _B1>::type
//                          ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:391:3: note: in instantiation of template class 'std::__and_<std::is_copy_assignable<double>, std::is_copy_assignable<int> >' requested here
//                 __and_<is_copy_assignable<_T1>,
//                 ^
// input_line_12:7:24: note: in instantiation of template class 'std::pair<double, int>' requested here
// std::pair<double, int> p2;
//                        ^
// In file included from input_line_1:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:1097:58: error: no member named 'value' in 'std::__is_referenceable<double, void>'
//   template<typename _Tp, bool = __is_referenceable<_Tp>::value>
//                                 ~~~~~~~~~~~~~~~~~~~~~~~~~^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:1112:14: note: in instantiation of default argument for '__is_move_assignable_impl<double>' required here
//     : public __is_move_assignable_impl<_Tp>::type
//              ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:139:26: note: in instantiation of template class 'std::is_move_assignable<double>' requested here
//     : public conditional<_B1::value, _B2, _B1>::type
//                          ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:402:3: note: in instantiation of template class 'std::__and_<std::is_move_assignable<double>, std::is_move_assignable<int> >' requested here
//                 __and_<is_move_assignable<_T1>,
//                 ^
// input_line_12:7:24: note: in instantiation of template class 'std::pair<double, int>' requested here
// std::pair<double, int> p2;
//                        ^
// In file included from input_line_1:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:139:31: error: no member named 'value' in 'std::__is_constructible_impl<double>'
//     : public conditional<_B1::value, _B2, _B1>::type
//                          ~~~~~^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:1224:14: note: in instantiation of template class 'std::__and_<std::__is_constructible_impl<double>, std::__is_implicitly_default_constructible_safe<double> >' requested here
//     : public __and_<__is_constructible_impl<_Tp>,
//              ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:139:26: note: in instantiation of template class 'std::__is_implicitly_default_constructible<double>' requested here
//     : public conditional<_B1::value, _B2, _B1>::type
//                          ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:227:36: note: in instantiation of template class 'std::__and_<std::__is_implicitly_default_constructible<double>, std::__is_implicitly_default_constructible<int> >' requested here
//                 typename enable_if<__and_<
//                                    ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:232:26: note: while substituting prior template arguments into non-type template parameter [with _U1 = double, _U2 = int]
//       _GLIBCXX_CONSTEXPR pair()
//                          ^~~~~~
// input_line_12:7:24: note: while substituting deduced template arguments into function template 'pair' [with _U1 = (no value), _U2 = (no value), $2 = (no value)]
// std::pair<double, int> p2;
//                        ^
// In file included from input_line_1:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:144:31: error: no member named 'value' in 'std::is_default_constructible<double>'
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//                          ~~~~~^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:238:36: note: in instantiation of template class 'std::__and_<std::is_default_constructible<double>, std::is_default_constructible<int>, std::__not_<std::__and_<std::__is_implicitly_default_constructible<double>, std::__is_implicitly_default_constructible<int> > > >' requested here
//                 typename enable_if<__and_<
//                                    ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:245:26: note: while substituting prior template arguments into non-type template parameter [with _U1 = double, _U2 = int]
//       explicit constexpr pair()
//                          ^~~~~~
// input_line_12:7:24: note: while substituting deduced template arguments into function template 'pair' [with _U1 = (no value), _U2 = (no value), $2 = (no value)]
// std::pair<double, int> p2;
//                        ^
// input_line_12:7:24: error: no matching constructor for initialization of 'std::pair<double, int>'
// std::pair<double, int> p2;
//                        ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:232:26: note: candidate template ignored: substitution failure [with _U1 = double, _U2 = int]
//       _GLIBCXX_CONSTEXPR pair()
//                          ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:245:26: note: candidate template ignored: substitution failure [with _U1 = double, _U2 = int]
//       explicit constexpr pair()
//                          ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:266:17: note: candidate constructor template not viable: requires 2 arguments, but 0 were provided
//       constexpr pair(const _T1& __a, const _T2& __b)
//                 ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:276:26: note: candidate constructor template not viable: requires 2 arguments, but 0 were provided
//       explicit constexpr pair(const _T1& __a, const _T2& __b)
//                          ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:300:19: note: candidate constructor template not viable: requires single argument '__p', but no arguments were provided
//         constexpr pair(const pair<_U1, _U2>& __p)
//                   ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:309:21: note: candidate constructor template not viable: requires single argument '__p', but no arguments were provided
//         explicit constexpr pair(const pair<_U1, _U2>& __p)
//                            ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:322:18: note: candidate constructor template not viable: requires 2 arguments, but 0 were provided
//        constexpr pair(_U1&& __x, const _T2& __y)
//                  ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:329:27: note: candidate constructor template not viable: requires 2 arguments, but 0 were provided
//        explicit constexpr pair(_U1&& __x, const _T2& __y)
//                           ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:336:18: note: candidate constructor template not viable: requires 2 arguments, but 0 were provided
//        constexpr pair(const _T1& __x, _U2&& __y)
//                  ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:343:17: note: candidate constructor template not viable: requires 2 arguments, but 0 were provided
//        explicit pair(const _T1& __x, _U2&& __y)
//                 ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:352:12: note: candidate constructor template not viable: requires 2 arguments, but 0 were provided
//         constexpr pair(_U1&& __x, _U2&& __y)
//                   ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:361:21: note: candidate constructor template not viable: requires 2 arguments, but 0 were provided
//         explicit constexpr pair(_U1&& __x, _U2&& __y)
//                            ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:371:12: note: candidate constructor template not viable: requires single argument '__p', but no arguments were provided
//         constexpr pair(pair<_U1, _U2>&& __p)
//                   ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:381:21: note: candidate constructor template not viable: requires single argument '__p', but no arguments were provided
//         explicit constexpr pair(pair<_U1, _U2>&& __p)
//                            ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:387:9: note: candidate constructor template not viable: requires 3 arguments, but 0 were provided
//         pair(piecewise_construct_t, tuple<_Args1...>, tuple<_Args2...>);
//         ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:452:9: note: candidate constructor template not viable: requires 4 arguments, but 0 were provided
//         pair(tuple<_Args1...>&, tuple<_Args2...>&,
//         ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:314:17: note: candidate constructor not viable: requires 1 argument, but 0 were provided
//       constexpr pair(const pair&) = default;    ///< Copy constructor
//                 ^
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:315:17: note: candidate constructor not viable: requires 1 argument, but 0 were provided
//       constexpr pair(pair&&) = default;         ///< Move constructor
//                 ^
// In file included from input_line_5:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/include/xeus/xinterpreter.hpp:13:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/functional:62:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/vector:67:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:401:66: error: no member named 'value' in 'std::is_same<std::pair<int, double>, std::pair<int, double> >'
//       static_assert(is_same<typename remove_cv<_Tp>::type, _Tp>::value,
//                     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
// input_line_12:11:37: note: in instantiation of template class 'std::vector<std::pair<int, double>, std::allocator<std::pair<int, double> > >' requested here
// std::vector<std::pair<int, double>> test;
//                                     ^
// In file included from input_line_5:1:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/include/xeus/xinterpreter.hpp:13:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/functional:62:
// In file included from /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/vector:67:
// /home/jlate/miniforge3/envs/cpp-jupyter/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:404:64: error: no member named 'value' in 'std::is_same<std::pair<int, double>, std::pair<int, double> >'
//       static_assert(is_same<typename _Alloc::value_type, _Tp>::value,
//                     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
// fatal error: too many errors emitted, stopping now [-ferror-limit=]
// Interpreter Error:

// %%
int n = 4;
const int INF = 1e9; // A large value representing "infinity"

// Adjacency list
// pair<neighbor, weight>
std::vector<std::vector<std::pair<int,int>>> adjList = {
    {{1,4}, {2,1}, {3,7}}, // A - B(4), C(1), D(7)
    {{0,4}, {2,2}},        // B - A(4), C(2)
    {{0,1}, {1,2}, {3,3}}, // C - A(1), B(2), D(3)
    {{0,7}, {2,3}}         // D - A(7), C(3)
};

// Adjacency matrix
// INF = no edge
std::vector<std::vector<int>> adjMatrix = {
//      A    B    C    D
    {   0,   4,   1,   7}, // A
    {   4,   0,   2, INF}, // B
    {   1,   2,   0,   3}, // C
    {   7, INF,   3,   0}  // D
};

// Print adjacency list (with letter labels and weights)
std::cout << "Undirected Weighted Adjacency List:\n";
for (int i = 0; i < n; ++i) {
    std::cout << char('A' + i) << ": ";
    for (const auto &p : adjList[i]) {
        int v = p.first;
        int w = p.second;
        std::cout << char('A' + v) << "(" << w << ") ";
    }
    std::cout << '\n';
}

// Print adjacency matrix
std::cout << "\nUndirected Weighted Adjacency Matrix (0 = no edge):\n";
std::cout << "  ";
for (int i = 0; i < n; ++i) 
    std::cout << char('A' + i) << ' ';
std::cout << '\n';

for (int i = 0; i < n; ++i) {
    std::cout << char('A' + i) << ' ';
    for (int j = 0; j < n; ++j)
        if (adjMatrix[i][j] == INF)
            std::cout << "∞" << ' ';
        else
            std::cout << adjMatrix[i][j] << ' ';
    std::cout << '\n';
}
// Out:
// Undirected Weighted Adjacency List:
// A: B(4) C(1) D(7)
// B: A(4) C(2)
// C: A(1) B(2) D(3)
// D: A(7) C(3)
//
// Undirected Weighted Adjacency Matrix (0 = no edge):
//   A B C D
// A 0 4 1 7
// B 4 0 2 ∞
// C 1 2 0 3
// D 7 ∞ 3 0
